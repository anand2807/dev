# %%
from dotenv import load_dotenv
import os
from IPython.display import Markdown
from openai import OpenAI

# %%
load_dotenv()

# %% [markdown]
# # let's write the first draft with OpenAI

# %%
with open("../input/0MOP-product-description.txt") as f:
PRODUCT_DESCRIPTION = f. read ()
PRODUCT_DESCRIPTION;

# %%
client2 = OpenAI(
api_key=os.environ[ 'XAI_API_KEY'],
base_url="https://api.x.ai/v1",

# %%
def to_pdf(filename_without_suffix, contents):
md_filename = filename_without_suffix + ".md"
with open(md_filename, "w") as f:
f.write(contents)
os.system (f"markdown-pdf {md_filename)")
